# %% [markdown]
# ## Question 1
#
# sql done in snowflake to set up question 1:
#
# -- Create a virtual warehouse named 'my_first_warehouse'
# CREATE OR REPLACE WAREHOUSE my_first_warehouse
# WITH
#    WAREHOUSE_SIZE = 'XSMALL',  -- Adjust size as needed (XSMALL, SMALL, etc.)
#    AUTO_SUSPEND = 300,  -- Suspend after 5 minutes of inactivity
#    AUTO_RESUME = TRUE;  -- Automatically resume when a query is run
#
# -- Use the warehouse in your session
# USE WAREHOUSE my_first_warehouse;

# %%
import snowflake.connector
import glob
import os
import pandas as pd

# Step 1: Connect to Snowflake
conn = snowflake.connector.connect(
    user='cds006',
    password='@Triton123',
    account='qla31786.east-us-2.azure',
    warehouse='my_first_warehouse',
    database='PURCHASEORDERDATA',
    schema='PUBLIC'
)

# Create a cursor object
cs = conn.cursor()

# Step 2: Create a Stage for Data Upload
cs.execute("CREATE STAGE IF NOT EXISTS purchase_stage")
print("Stage 'purchase_stage' created or exists.")

# Step 3: Automate the Upload of CSV Files to the Stage
# Define the path where your CSV files are located
csv_files_path = r"/home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/*.csv"  # Ensure only CSV files are targeted

# Check if files are being correctly identified
csv_files = glob.glob(csv_files_path)
if not csv_files:
    print("No CSV files found in the specified directory. Please check the path:", csv_files_path)
else:
    print(f"Found {len(csv_files)} CSV files to upload.")

# Step 4: Pre-process CSV files to clean the timestamp format
for file_path in csv_files:
    if os.path.isfile(file_path):
        try:
            # Load the CSV file into a DataFrame to clean the LASTEDITEDWHEN column
            df = pd.read_csv(file_path)
            # Convert the LASTEDITEDWHEN column to a proper timestamp format
            if 'LASTEDITEDWHEN' in df.columns:
                df['LASTEDITEDWHEN'] = pd.to_datetime(df['LASTEDITEDWHEN'], errors='coerce')
            
            # Save the cleaned data back to the file
            df.to_csv(file_path, index=False)
            print(f"Cleaned timestamps in {file_path}")
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

# Iterate over all CSV files and attempt to upload them to Snowflake
for file_path in csv_files:
    if os.path.isfile(file_path):
        try:
            print(f"Attempting to upload file: {file_path}")
            # Execute PUT command to upload the file to the Snowflake stage
            cs.execute(f"PUT 'file://{file_path}' @purchase_stage auto_compress=true")
            print(f"Uploaded {file_path} to the stage successfully.")
        except Exception as e:
            print(f"Error uploading {file_path}: {e}")
    else:
        print(f"Skipping {file_path}, not a valid file.")

# Step 5: Verify files are in stage
cs.execute("LIST @purchase_stage")
stage_files = cs.fetchall()
if stage_files:
    print(f"Files in stage: {stage_files}")
else:
    print("No files found in stage. Ensure the PUT command executed correctly and files were accessible.")

# Step 6: Create the Table to Load Data
cs.execute("""
    CREATE OR REPLACE TABLE MonthlyPurchaseOrderData (
        PurchaseOrderID INTEGER,
        SupplierID INTEGER,
        OrderDate DATE,
        DeliveryMethodID INTEGER,
        ContactPersonID INTEGER,
        ExpectedDeliveryDate DATE,
        SupplierReference STRING,
        IsOrderFinalized BOOLEAN,
        Comments STRING,
        InternalComments STRING,
        LastEditedBy INTEGER,
        LastEditedWhen TIMESTAMP_NTZ,
        PurchaseOrderLineID INTEGER,
        StockItemID INTEGER,
        OrderedOuters INTEGER,
        Description STRING,
        ReceivedOuters INTEGER,
        PackageTypeID INTEGER,
        ExpectedUnitPricePerOuter FLOAT,
        LastReceiptDate DATE,
        IsOrderLineFinalized BOOLEAN,
        Right_LastEditedBy INTEGER,
        Right_LastEditedWhen TIMESTAMP_NTZ
    )
""")
print("Table 'MonthlyPurchaseOrderData' created successfully.")

# Step 7: Load Data from Stage to the Table with ON_ERROR option
cs.execute("""
    COPY INTO MonthlyPurchaseOrderData
    FROM @purchase_stage
    FILE_FORMAT = (TYPE = 'CSV', FIELD_OPTIONALLY_ENCLOSED_BY = '"', SKIP_HEADER = 1)
    ON_ERROR = 'CONTINUE';  -- This will skip rows with errors
""")
print("Data loaded into 'MonthlyPurchaseOrderData' successfully.")

# Step 8: Close the Cursor and Connection
cs.close()
conn.close()
# Out:
# Stage 'purchase_stage' created or exists.
# Found 41 CSV files to upload.
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-4.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-1.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-12.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-10.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-3.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-3.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-8.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-7.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-12.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-1.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-10.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-3.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-1.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-5.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-9.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-5.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-2.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-11.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-11.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-5.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-2.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-2.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-6.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-1.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-6.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-5.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-4.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-9.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-8.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-9.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-7.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-11.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-6.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-12.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-3.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-8.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-2.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-7.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-4.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-4.csv
# Cleaned timestamps in /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-10.csv
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-4.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-4.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-1.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-1.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-12.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-12.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-10.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-10.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-3.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-3.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-3.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-3.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-8.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-8.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-7.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-7.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-12.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-12.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-1.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-1.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-10.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-10.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-3.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-3.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-1.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-1.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-5.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-5.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-9.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-9.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-5.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-5.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-2.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-2.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-11.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-11.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-11.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-11.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-5.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-5.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-2.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-2.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-2.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-2.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-6.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-6.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-1.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-1.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-6.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-6.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-5.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-5.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-4.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-4.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-9.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-9.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-8.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-8.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-9.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-9.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-7.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-7.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-11.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-11.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-6.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-6.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-12.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2014-12.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-3.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-3.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-8.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-8.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-2.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-2.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-7.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-7.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-4.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2015-4.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-4.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2016-4.csv to the stage successfully.
# Attempting to upload file: /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-10.csv
# Uploaded /home/jovyan/464/SQLETLSnowflake/CaseData1/Monthly PO Data/2013-10.csv to the stage successfully.
# Files in stage: [('purchase_stage/2013-1.csv.gz', 7024, 'efeae213eaf03c21310b4b85a5f1c66e', 'Thu, 5 Sep 2024 00:27:26 GMT'), ('purchase_stage/2013-10.csv.gz', 3392, 'ab7d65d88bd3e4800dd36a7a5b79e6e5', 'Thu, 5 Sep 2024 00:27:37 GMT'), ('purchase_stage/2013-11.csv.gz', 3120, '0cc889036a7c1a786349701b5a633d17', 'Thu, 5 Sep 2024 00:27:35 GMT'), ('purchase_stage/2013-12.csv.gz', 3040, '528204d6c937526231e482f809efbfe5', 'Thu, 5 Sep 2024 00:27:28 GMT'), ('purchase_stage/2013-2.csv.gz', 2432, 'd64208b27c80b32b82d43c4e99ade7e5', 'Thu, 5 Sep 2024 00:27:36 GMT'), ('purchase_stage/2013-3.csv.gz', 2928, 'e5526c110cc7009eec04f02baa35d47a', 'Thu, 5 Sep 2024 00:27:27 GMT'), ('purchase_stage/2013-4.csv.gz', 3168, '605a271f4c4b8ab79aed8278e409352d', 'Thu, 5 Sep 2024 00:27:26 GMT'), ('purchase_stage/2013-5.csv.gz', 3264, '65a9038785eb89d9e3a4165ba0bb323b', 'Thu, 5 Sep 2024 00:27:32 GMT'), ('purchase_stage/2013-6.csv.gz', 3088, '21651d96f47ed16f04fa58ef7de5e56a', 'Thu, 5 Sep 2024 00:27:35 GMT'), ('purchase_stage/2013-7.csv.gz', 3312, '15dcd17737586ba40533bb6e7d68180a', 'Thu, 5 Sep 2024 00:27:36 GMT'), ('purchase_stage/2013-8.csv.gz', 3296, '2f68c8128122d1918a4607fa8a5c801e', 'Thu, 5 Sep 2024 00:27:36 GMT'), ('purchase_stage/2013-9.csv.gz', 3056, 'd184c07ec242e1ba6fd6655dc8658091', 'Thu, 5 Sep 2024 00:27:33 GMT'), ('purchase_stage/2014-1.csv.gz', 3264, 'a118a2283884174cc5431f62cad7647e', 'Thu, 5 Sep 2024 00:27:31 GMT'), ('purchase_stage/2014-10.csv.gz', 3680, 'ba5200492919116fb77fe2921e007262', 'Thu, 5 Sep 2024 00:27:28 GMT'), ('purchase_stage/2014-11.csv.gz', 3456, '0a77687d5dc11b9c771c41d6429ccf61', 'Thu, 5 Sep 2024 00:27:30 GMT'), ('purchase_stage/2014-12.csv.gz', 3648, 'fcd2612a83775109cabc1ca98f0df227', 'Thu, 5 Sep 2024 00:27:35 GMT'), ('purchase_stage/2014-2.csv.gz', 3040, '72409d7fffeb2cc3694ffcf65bf0aa4c', 'Thu, 5 Sep 2024 00:27:30 GMT'), ('purchase_stage/2014-3.csv.gz', 3040, 'ed134b268c6782a3c39ef0e58b34a83a', 'Thu, 5 Sep 2024 00:27:27 GMT'), ('purchase_stage/2014-4.csv.gz', 3216, '61d367627ad64de4169b37c278cc6b57', 'Thu, 5 Sep 2024 00:27:32 GMT'), ('purchase_stage/2014-5.csv.gz', 3360, '6c64f6bc0f7eba31d1fe88bc4df0af77', 'Thu, 5 Sep 2024 00:27:29 GMT'), ('purchase_stage/2014-6.csv.gz', 3376, '0c2ce3862a3f50bba970f8a26682ad47', 'Thu, 5 Sep 2024 00:27:32 GMT'), ('purchase_stage/2014-7.csv.gz', 3648, 'dc17d81783fb34126a515b4c275d9ce6', 'Thu, 5 Sep 2024 00:27:28 GMT'), ('purchase_stage/2014-8.csv.gz', 3344, '3d3cf898a0137250e9e8e1fd99eb53c2', 'Thu, 5 Sep 2024 00:27:27 GMT'), ('purchase_stage/2014-9.csv.gz', 3456, 'ce7f61a386a430dd54f30aa79e34d7e7', 'Thu, 5 Sep 2024 00:27:34 GMT'), ('purchase_stage/2015-1.csv.gz', 3456, '4aea27891200279223cf49e66965fa21', 'Thu, 5 Sep 2024 00:27:28 GMT'), ('purchase_stage/2015-10.csv.gz', 3568, 'a07990f7121b66bb442b83bae9443e73', 'Thu, 5 Sep 2024 00:27:27 GMT'), ('purchase_stage/2015-11.csv.gz', 3376, 'f2ead3b9f54e19a2a6220ec2b2f3b63e', 'Thu, 5 Sep 2024 00:27:30 GMT'), ('purchase_stage/2015-12.csv.gz', 3712, '4a3f70caab5888bb468443e24737561d', 'Thu, 5 Sep 2024 00:27:26 GMT'), ('purchase_stage/2015-2.csv.gz', 3232, '064664779d68ea1ddd6be3530886bed8', 'Thu, 5 Sep 2024 00:27:31 GMT'), ('purchase_stage/2015-3.csv.gz', 3536, '112dedf56e3140a4e39867de4c4c1319', 'Thu, 5 Sep 2024 00:27:36 GMT'), ('purchase_stage/2015-4.csv.gz', 3552, '1b92f48ecb4506650a338a1b257ef6ed', 'Thu, 5 Sep 2024 00:27:37 GMT'), ('purchase_stage/2015-5.csv.gz', 3504, '566f832a530b0c2f2c4fb281ff2e422a', 'Thu, 5 Sep 2024 00:27:30 GMT'), ('purchase_stage/2015-6.csv.gz', 3328, '90c69a9affabb9df75fbf5ee929ee080', 'Thu, 5 Sep 2024 00:27:31 GMT'), ('purchase_stage/2015-7.csv.gz', 3568, '2dca1c2b77ad998f336ca560a52251d3', 'Thu, 5 Sep 2024 00:27:34 GMT'), ('purchase_stage/2015-8.csv.gz', 3264, '464097779662836e0561fda7e1052345', 'Thu, 5 Sep 2024 00:27:33 GMT'), ('purchase_stage/2015-9.csv.gz', 3552, '0096bbdb123463e53541eecaae549b12', 'Thu, 5 Sep 2024 00:27:29 GMT'), ('purchase_stage/2016-1.csv.gz', 3824, '56cd4b52289b7fd3bdae7889d9086bb9', 'Thu, 5 Sep ...
# Table 'MonthlyPurchaseOrderData' created successfully.
# Data loaded into 'MonthlyPurchaseOrderData' successfully.

# %% [markdown]
# ## Question 2
#
# sql done in snowflake for question 2:
#
# -- Add the POAmount column to the table
# ALTER TABLE MonthlyPurchaseOrderData
# ADD COLUMN POAmount FLOAT;
#
# -- Update the POAmount column with the calculated values
# UPDATE MonthlyPurchaseOrderData
# SET POAmount = ReceivedOuters * ExpectedUnitPricePerOuter;
#
# -- Select a few rows to check the POAmount calculations
# SELECT PurchaseOrderID, ReceivedOuters, ExpectedUnitPricePerOuter, POAmount
# FROM MonthlyPurchaseOrderData
# LIMIT 5;
#
# -- Create a calculated field that shows purchase order totals for each order
# SELECT
#     PurchaseOrderID,
#     SUM(POAmount) AS TotalPOAmount
# FROM
#     MonthlyPurchaseOrderData
# GROUP BY
#     PurchaseOrderID
# ORDER BY
#     PurchaseOrderID
# LIMIT 10;

# %% [markdown]
# ## Question 3
#
# validation to make sure code worked in snowflake sql after q3 code is run
# SELECT xml_column FROM RawXMLData LIMIT 5;
#
# SELECT x.value
# FROM RawXMLData, LATERAL FLATTEN(input => xml_column) x
# LIMIT 10;
#
# SELECT x.value
# FROM RawXMLData,
# LATERAL FLATTEN(input => xml_column) x
# LIMIT 10;
#
# SELECT * FROM SupplierInvoices LIMIT 10;

# %%
import snowflake.connector
import os

# Step 1: Connect to Snowflake
conn = snowflake.connector.connect(
    user='cds006',
    password='@Triton123',
    account='qla31786.east-us-2.azure',
    warehouse='my_first_warehouse',
    database='PURCHASEORDERDATA',
    schema='PUBLIC'
)

# Create a cursor object
cs = conn.cursor()

# Step 2: Create a stage for uploading XML data
cs.execute("CREATE OR REPLACE STAGE xml_stage")
print("Stage 'xml_stage' created or exists.")

# Step 3: Create an XML file format in Snowflake
cs.execute("""
    CREATE OR REPLACE FILE FORMAT xml_file_format 
    TYPE = 'XML' 
    STRIP_OUTER_ELEMENT = TRUE
""")
print("XML file format 'xml_file_format' created.")

# Step 4: Upload the XML file to the Snowflake stage
xml_file_path = "/home/jovyan/464/SQLETLSnowflake/CaseData1/Supplier Transactions XML.xml"
put_command = f"PUT 'file://{xml_file_path}' @xml_stage auto_compress=true"
cs.execute(put_command)
print("XML file uploaded to stage.")

# Step 5: Create or replace the SupplierInvoices table
cs.execute("""
    CREATE OR REPLACE TABLE SupplierInvoices (
        SupplierTransactionID INTEGER,
        SupplierID INTEGER,
        TransactionTypeID INTEGER,
        PurchaseOrderID INTEGER,
        PaymentMethodID INTEGER,
        SupplierInvoiceNumber STRING,
        TransactionDate DATE,
        AmountExcludingTax FLOAT,
        TaxAmount FLOAT,
        TransactionAmount FLOAT,
        OutstandingBalance FLOAT,
        FinalizationDate DATE,
        IsFinalized BOOLEAN,
        LastEditedBy INTEGER,
        LastEditedWhen TIMESTAMP_NTZ
    )
""")
print("Table 'SupplierInvoices' created or replaced successfully.")

# Step 6: Load and shred the XML data into the SupplierInvoices table
try:
    cs.execute("""
        COPY INTO SupplierInvoices 
        FROM @xml_stage 
        FILE_FORMAT = (TYPE = 'XML') 
        ON_ERROR = 'CONTINUE'
        PATTERN = '.*Supplier Transactions XML.xml'
    """)
    print("XML data copied to 'SupplierInvoices' successfully.")
except Exception as e:
    print(f"Error loading XML data: {e}")

# Step 7: Verify Data in SupplierInvoices
try:
    cs.execute("SELECT * FROM SupplierInvoices LIMIT 10;")
    shredded_data = cs.fetchall()
    for row in shredded_data:
        print(row)
except Exception as e:
    print(f"Error retrieving data from 'SupplierInvoices': {e}")

# Step 8: Close the cursor and connection
cs.close()
conn.close()
# Out:
# Stage 'xml_stage' created or exists.
# XML file format 'xml_file_format' created.
# XML file uploaded to stage.
# Table 'SupplierInvoices' created or replaced successfully.
# Error loading XML data: 002019 (0A000): SQL compilation error:
# XML file format can produce one and only one column of type variant, object, or array. Load data into separate columns using copy with transformation.
